# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize_scalar
from scipy.interpolate import RectBivariateSpline
from scipy.interpolate import RegularGridInterpolator

# === Paramètres ===
r = 0.03
mu = 0.05
sigma = 0.30
gamma = 0.5
K = 100  # strike du call
T = 1.0
n = 80
p = 0.5

delta_t = T / n

# === Grilles ===
W_min, W_max = 1e-3, 200
S_min, S_max = 10, 200
N_W, N_S = 200, 80
W_grid = np.linspace(W_min, W_max, N_W)
S_grid = np.linspace(S_min, S_max, N_S)

# === Fonction utilité CRRA ===
def u(w, gamma):
    if w <= 0:
        return -1e12
    return w**(1 - gamma) / (1 - gamma) if gamma != 1 else np.log(w)

# === Initialisation terminale V_T(W, S) ===
V = {}
pi_store = {}

V[n] = np.zeros((N_W, N_S))
pi_store[n] = np.zeros((N_W, N_S))

for i, w in enumerate(W_grid):
    for j, s in enumerate(S_grid):
        payoff = max(s - K, 0.0)  # short call payoff
        V[n][i, j] = u(w - payoff, gamma)

# === Backward induction ===
for t in reversed(range(n)):
    V[t] = np.zeros((N_W, N_S))
    pi_store[t] = np.zeros((N_W, N_S))


    # Interpolateur pour V_{t+1}
    interp = RegularGridInterpolator((W_grid, S_grid), V[t+1], method='linear', bounds_error=False, fill_value=None)


    for i, w in enumerate(W_grid):
        for j, s in enumerate(S_grid):

            def objective(pi):
                A = 1 + r * delta_t
                B = (mu - r) * delta_t
                C = sigma * np.sqrt(delta_t)

                s_up = s * np.exp(sigma * np.sqrt(delta_t))
                s_down = s * np.exp(-sigma * np.sqrt(delta_t))

                w_up = w * (A + pi * (B + C))
                w_down = w * (A + pi * (B - C))

                if w_up <= 0 or w_down <= 0:
                    return np.inf

                # Pass the coordinates as a list of [w, s]
                V_up = interp([[w_up, s_up]])[0]
                V_down = interp([[w_down, s_down]])[0]
                return -(p * V_up + (1 - p) * V_down)

            res = minimize_scalar(objective, bounds=(0, 3), method='bounded')
            pi_opt = res.x
            V_opt = -res.fun

            V[t][i, j] = V_opt
            pi_store[t][i, j] = pi_opt
    
    print(f"Processing time step {t} of {n-1}...")


# === Exemple : stratégie à t = 0 ===
plt.figure(figsize=(8, 6))
S_idx_plot = [0, N_S//4, N_S//2, 3*N_S//4, N_S-1]
for j in S_idx_plot:
    plt.plot(W_grid, pi_store[0][:, j], label=f"S₀ = {round(S_grid[j],1)}")

plt.title("Stratégie optimale π₀(W, S₀) avec short call")
plt.xlabel("Richesse W")
plt.ylabel("Proportion optimale π")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 76
#      73     V_down = interp([[w_down, s_down]])[0]
#      74     return -(p * V_up + (1 - p) * V_down)
# ---> 76 res = minimize_scalar(objective, bounds=(0, 3), method='bounded')
#      77 pi_opt = res.x
#      78 V_opt = -res.fun
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_minimize.py:966, in minimize_scalar(fun, bracket, bounds, args, method, tol, options)
#     963     if bounds is None:
#     964         raise ValueError('The `bounds` parameter is mandatory for '
#     965                          'method `bounded`.')
# --> 966     res = _minimize_scalar_bounded(fun, bounds, args, **options)
#     967 elif meth == 'golden':
#     968     res = _recover_from_bracket_error(_minimize_scalar_golden,
#     969                                       fun, bracket, args, **options)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/optimize/_optimize.py:2321, in _minimize_scalar_bounded(func, bounds, args, xatol, maxiter, disp, **unknown_options)
#    2319 si = np.sign(rat) + (rat == 0)
#    2320 x = xf + si * np.maximum(np.abs(rat), tol1)
# -> 2321 fu = func(x, *args)
#    2322 num += 1
#    2323 fmin_data = (num, x, fu)
#
# Cell In[5], line 73, in objective(pi)
#      71 # Pass the coordinates as a list of [w, s]
#      72 V_up = interp([[w_up, s_up]])[0]
# ---> 73 V_down = interp([[w_down, s_down]])[0]
#      74 return -(p * V_up + (1 - p) * V_down)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/interpolate/_rgi.py:415, in RegularGridInterpolator.__call__(self, xi, method, nu)
#     412 xi, xi_shape, ndim, nans, out_of_bounds = self._prepare_xi(xi)
#     414 if method == "linear":
# --> 415     indices, norm_distances = self._find_indices(xi.T)
#     416     if (ndim == 2 and hasattr(self.values, 'dtype') and
#     417             self.values.ndim == 2 and self.values.flags.writeable and
#     418             self.values.dtype in (np.float64, np.complex128) and
#    (...)
#     421         # cannot support non-writeable values
#     422         # a fast path
#     423         out = np.empty(indices.shape[1], dtype=self.values.dtype)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/interpolate/_rgi.py:590, in RegularGridInterpolator._find_indices(self, xi)
#     589 def _find_indices(self, xi):
# --> 590     return find_indices(self.grid, xi)
#
# File _rgi_cython.pyx:93, in scipy.interpolate._rgi_cython.find_indices()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/core/numeric.py:63, in _zeros_like_dispatcher(a, dtype, order, subok, shape)
#      38 array_function_dispatch = functools.partial(
#      39     overrides.array_function_dispatch, module='numpy')
#      42 __all__ = [
#      43     'newaxis', 'ndarray', 'flatiter', 'nditer', 'nested_iters', 'ufunc',
#      44     'arange', 'array', 'asarray', 'asanyarray', 'ascontiguousarray',
#    (...)
#      59     'MAY_SHARE_EXACT', '_get_promotion_state', '_set_promotion_state',
#      60     '_using_numpy2_behavior']
# ---> 63 def _zeros_like_dispatcher(a, dtype=None, order=None, subok=None, shape=None):
#      64     return (a,)
#      67 @array_function_dispatch(_zeros_like_dispatcher)
#      68 def zeros_like(a, dtype=None, order='K', subok=True, shape=None):
#
# KeyboardInterrupt:
